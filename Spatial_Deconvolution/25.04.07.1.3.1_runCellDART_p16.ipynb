# %%
spatialSample="p16" #p16 or spider. Key.

# %%
import scanpy as sc
from CellDART.pred_cellf_celldart import pred_cellf_celldart

#This takes a moment.

# %%
adata_sp=sc.read_h5ad(f"/home/hezhou/_Projects/25.02.27_Jielin_Senescence/25.04.07_prepareData/_Data/dataSpatial_{spatialSample}.h5ad")
adata_sc=sc.read_h5ad("/home/hezhou/_Projects/25.02.27_Jielin_Senescence/25.04.07_prepareData/_Data/dataSnRNASeq.h5ad")

#This takes a moment.

# %%
adata_sp.X.shape #Cell by gene.
# Out:
# (1808, 19465)

# %%
adata_sc.X.shape #Cell by gene.
# Out:
# (44573, 32285)

# %%
adata_sp2=pred_cellf_celldart(adata_sp=adata_sp,adata_sc=adata_sc,count_from_raw=False,
                              gpu=False,celltype="celltype",num_markers=20,
                              nmix=8,npseudo=20000,alpha=0.6,alpha_lr=5,batch_size=512,
                              emb_dim=64,n_iterations=3000,init_train_epoch=10,
                              outdir=f"/home/hezhou/_Projects/25.02.27_Jielin_Senescence/25.04.07_spatialCellTypes/1.3_resultCellDART/{spatialSample}/",
                              return_anndata=True)

#This takes about 10 minutes.
# Out:
# CPU will be used
# 2025-04-08 22:09:40.719889: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/R/lib:/.singularity.d/libs:/lib:/usr/local/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/java-11-openjdk-amd64/lib/server:/.singularity.d/libs
# 2025-04-08 22:09:40.719929: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Shape of the provided spatial data is (1808, 19465)
# Shape of the provided single-cell data is (44573, 32285)
# Total number of marker genes:  166
# Size of spatial, single-cell, pseudospot, and cell fraction data: (1808, 166) (44573, 166) (20000, 166) (20000, 10)
# 2025-04-08 22:17:40.539741: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/R/lib:/.singularity.d/libs:/lib:/usr/local/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/java-11-openjdk-amd64/lib/server:/.singularity.d/libs
# 2025-04-08 22:17:40.539784: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-04-08 22:17:40.539813: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ppxhpcnode01): /proc/driver/nvidia/version does not exist
# Train on 20000 samples
# 2025-04-08 22:17:42.379603: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-08 22:17:42.457063: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Epoch 1/10
# 20000/20000 [==============================] - 2s 77us/sample - loss: 0.6808 - mae: 0.0783
# Epoch 2/10
# 20000/20000 [==============================] - 0s 24us/sample - loss: 0.3495 - mae: 0.0544
# Epoch 3/10
# 20000/20000 [==============================] - 0s 22us/sample - loss: 0.2191 - mae: 0.0414
# Epoch 4/10
# 20000/20000 [==============================] - 0s 22us/sample - loss: 0.1739 - mae: 0.0361
# Epoch 5/10
# 20000/20000 [==============================] - 0s 21us/sample - loss: 0.1543 - mae: 0.0337
# Epoch 6/10
# 20000/20000 [==============================] - 0s 22us/sample - loss: 0.1449 - mae: 0.0327
# Epoch 7/10
# 20000/20000 [==============================] - 0s 21us/sample - loss: 0.1371 - mae: 0.0317
# Epoch 8/10
# 20000/20000 [==============================] - 0s 21us/sample - loss: 0.1341 - mae: 0.0314
# Epoch 9/10
# 20000/20000 [==============================] - 0s 22us/sample - loss: 0.1288 - mae: 0.0306
# Epoch 10/10
# 20000/20000 [==============================] - 0s 21us/sample - loss: 0.1259 - mae: 0.0303
# initial_train_done
# Iteration 99, source loss =  2.321, discriminator acc = 0.917
# Iteration 199, source loss =  1.149, discriminator acc = 0.108
# Iteration 299, source loss =  0.597, discriminator acc = 0.180
# Iteration 399, source loss =  0.802, discriminator acc = 0.069
# Iteration 499, source loss =  0.439, discriminator acc = 0.003
# Iteration 599, source loss =  0.329, discriminator acc = 0.120
# Iteration 699, source loss =  0.697, discriminator acc = 0.000
# Iteration 799, source loss =  0.357, discriminator acc = 0.000
# Iteration 899, source loss =  0.406, discriminator acc = 0.689
# Iteration 999, source loss =  0.258, discriminator acc = 0.001
# Iteration 1099, source loss =  0.258, discriminator acc = 0.068
# Iteration 1199, source loss =  0.363, discriminator acc = 0.173
# Iteration 1299, source loss =  0.318, discriminator acc = 0.000
# Iteration 1399, source loss =  0.296, discriminator acc = 0.479
# Iteration 1499, source loss =  0.357, discriminator acc = 0.001
# Iteration 1599, source loss =  0.399, discriminator acc = 0.917
# Iteration 1699, source loss =  0.293, discriminator acc = 0.009
# Iteration 1799, source loss =  0.270, discriminator acc = 0.001
# Iteration 1899, source loss =  0.532, discriminator acc = 0.889
# Iteration 1999, source loss =  0.283, discriminator acc = 0.063
# Iteration 2099, source loss =  0.429, discriminator acc = 0.278
# Iteration 2199, source loss =  0.277, discriminator acc = 0.755
# Iteration 2299, source loss =  0.336, discriminator acc = 0.917
# Iteration 2399, source loss =  0.397, discriminator acc = 0.000
# Iteration 2499, source loss =  0.435, discriminator acc = 0.738
# Iteration 2599, source loss =  0.337, discriminator acc = 0.001
# Iteration 2699, source loss =  0.345, discriminator acc = 0.236
# Iteration 2799, source loss =  0.285, discriminator acc = 0.008
# Iteration 2899, source loss =  0.331, discriminator acc = 0.105
# Iteration 2999, source loss =  0.305, discriminator acc = 0.648
# Cell fraction data for was saved
# Spatial anndata was saved
# Model and python data files were saved

# %%
adata_sp2.obs
# Out:
#                     nCount_Spatial  nFeature_Spatial  Immune-B cells_cellf  \
# AACACGTTGATACCGC-1          6940.0              2503              0.007433
# AACAGGCCATTGTCAC-1          6955.0              2493              0.015314
# AACAGTATCCGCCTGG-1         12969.0              4326              0.002448
# AACATACTCCACAGTT-1         10307.0              3102              0.010585
# AACATAGGTTGGCACC-1          5861.0              2349              0.008917
# ...                            ...               ...                   ...
# TGTTCGTGGCGTCGTG-1          6127.0              2356              0.007458
# TGTTGCCAGTCGCCTG-1          4495.0              1856              0.016800
# TGTTGGCCTGTAGCGG-1          8029.0              3132              0.001036
# TGTTGGTGCGGAATCA-1          6079.0              2250              0.008909
# TGTTGGTGGACTCAGG-1          5242.0              2057              0.012446
#
#                     Dentritic cells_cellf  Immune-T cells_cellf  \
# AACACGTTGATACCGC-1               0.003532              0.008226
# AACAGGCCATTGTCAC-1               0.008235              0.012402
# AACAGTATCCGCCTGG-1               0.001621              0.003848
# AACATACTCCACAGTT-1               0.005709              0.010534
# AACATAGGTTGGCACC-1               0.006163              0.009198
# ...                                   ...                   ...
# TGTTCGTGGCGTCGTG-1               0.003618              0.011480
# TGTTGCCAGTCGCCTG-1               0.008103              0.011310
# TGTTGGCCTGTAGCGG-1               0.001187              0.000937
# TGTTGGTGCGGAATCA-1               0.004764              0.009953
# TGTTGGTGGACTCAGG-1               0.006411              0.010859
#
#                     Macrophages_cellf  Cardiomyocytes_cellf  \
# AACACGTTGATACCGC-1           0.225521              0.087694
# AACAGGCCATTGTCAC-1           0.335168              0.079122
# AACAGTATCCGCCTGG-1           0.128073              0.058878
# AACATACTCCACAGTT-1           0.250244              0.062694
# AACATAGGTTGGCACC-1           0.263576              0.029656
# ...                               ...                   ...
# TGTTCGTGGCGTCGTG-1           0.234885              0.076791
# TGTTGCCAGTCGCCTG-1           0.280466              0.059779
# TGTTGGCCTGTAGCGG-1           0.138702              0.000192
# TGTTGGTGCGGAATCA-1           0.278253              0.090609
# TGTTGGTGGACTCAGG-1           0.291672              0.076312
#
#                     Smooth muscle cells_cellf  Pericytes_cellf  \
# AACACGTTGATACCGC-1                   0.043226         0.117578
# AACAGGCCATTGTCAC-1                   0.030334         0.095610
# AACAGTATCCGCCTGG-1                   0.035798         0.165525
# AACATACTCCACAGTT-1                   0.033595         0.153404
# AACATAGGTTGGCACC-1                   0.035174         0.165084
# ...                                       ...              ...
# TGTTCGTGGCGTCGTG-1                   0.033002         0.217795
# TGTTGCCAGTCGCCTG-1                   0.027223         0.085395
# TGTTGGCCTGTAGCGG-1                   0.000764         0.027672
# TGTTGGTGCGGAATCA-1                   0.023766         0.085054
# TGTTGGTGGACTCAGG-1                   0.026334         0.091334
#
#                     Endothelial cells_cellf  Fibroblasts_cellf  \
# AACACGTTGATACCGC-1                 0.168031           0.321685
# AACAGGCCATTGTCAC-1                 0.130352           0.269552
# AACAGTATCCGCCTGG-1                 0.138633           0.451679
# AACATACTCCACAGTT-1                 0.175724           0.276485
# AACATAGGTTGGCACC-1                 0.105272           0.351965
# ...                                     ...                ...
# TGTTCGTGGCGTCGTG-1                 0.133211           0.268858
# TGTTGCCAGTCGCCTG-1                 0.158718           0.333332
# TGTTGGCCTGTAGCGG-1                 0.064354           0.758952
# TGTTGGTGCGGAATCA-1                 0.104040           0.378233
# TGTTGGTGGACTCAGG-1                 0.156313           0.310802
#
#                     Epicardial cells_cellf
# AACACGTTGATACCGC-1                0.017074
# AACAGGCCATTGTCAC-1                0.023911
# AACAGTATCCGCCTGG-1                0.013499
# AACATACTCCACAGTT-1                0.021026
# AACATAGGTTGGCACC-1                0.024995
# ...                                    ...
# TGTTCGTGGCGTCGTG-1                0.012902
# TGTTGCCAGTCGCCTG-1                0.018874
# TGTTGGCCTGTAGCGG-1                0.006205
# TGTTGGTGCGGAATCA-1                0.016419
# TGTTGGTGGACTCAGG-1                0.017517
#
# [1808 rows x 12 columns]
